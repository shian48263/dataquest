# %%
import pandas as pd
import numpy as np

# %%
fandango = pd.read_csv('fandango_score_comparison.csv')
print(fandango.index)
fandango.head()
# Out:
# RangeIndex(start=0, stop=146, step=1)
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
# ...

# %%
first_last = fandango.iloc[[fandango.index[0], fandango.index[-1]]]
first_last
# Out:
#                                    FILM  RottenTomatoes  RottenTomatoes_User  \
# 0        Avengers: Age of Ultron (2015)              74                   86
# 145  Kumiko, The Treasure Hunter (2015)              87                   63
#
#      Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0            66              7.1   7.8             5.0                   4.5
# 145          68              6.4   6.7             3.5                   3.5
#
#      RT_norm  RT_user_norm         ...           IMDB_norm  RT_norm_round  \
# 0       3.70          4.30         ...                3.90            3.5
# 145     4.35          3.15         ...                3.35            4.5
#
#      RT_user_norm_round  Metacritic_norm_round  Metacritic_user_norm_round  \
# 0                   4.5                    3.5                         3.5
# 145                 3.0                    3.5                         3.0
#
# ...

# %%
fandango_films = fandango.set_index('FILM', inplace=False, drop=False)
fandango_films.head()
# Out:
#                                                           FILM  \
# FILM
# Avengers: Age of Ultron (2015)  Avengers: Age of Ultron (2015)
# Cinderella (2015)                            Cinderella (2015)
# Ant-Man (2015)                                  Ant-Man (2015)
# Do You Believe? (2015)                  Do You Believe? (2015)
# Hot Tub Time Machine 2 (2015)    Hot Tub Time Machine 2 (2015)
#
#                                 RottenTomatoes  RottenTomatoes_User  \
# FILM
# Avengers: Age of Ultron (2015)              74                   86
# Cinderella (2015)                           85                   80
# Ant-Man (2015)                              80                   90
# Do You Believe? (2015)                      18                   84
# Hot Tub Time Machine 2 (2015)               14                   28
#
#                                 Metacritic  Metacritic_User  IMDB  \
# FILM
# Avengers: Age of Ultron (2015)          66              7.1   7.8
# ...

# %%
fandango_films[:1]
# Out:
#                                                           FILM  \
# FILM
# Avengers: Age of Ultron (2015)  Avengers: Age of Ultron (2015)
#
#                                 RottenTomatoes  RottenTomatoes_User  \
# FILM
# Avengers: Age of Ultron (2015)              74                   86
#
#                                 Metacritic  Metacritic_User  IMDB  \
# FILM
# Avengers: Age of Ultron (2015)          66              7.1   7.8
#
#                                 Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# FILM
# Avengers: Age of Ultron (2015)             5.0                   4.5      3.7
#
#                                 RT_user_norm         ...           IMDB_norm  \
# FILM                                                 ...
# Avengers: Age of Ultron (2015)           4.3         ...                 3.9
#
#                                 RT_norm_round  RT_user_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)            3.5                 4.5
#
# ...

# %%
fandango_films.iloc[0]
# Out:
# FILM                          Avengers: Age of Ultron (2015)
# RottenTomatoes                                            74
# RottenTomatoes_User                                       86
# Metacritic                                                66
# Metacritic_User                                          7.1
# IMDB                                                     7.8
# Fandango_Stars                                             5
# Fandango_Ratingvalue                                     4.5
# RT_norm                                                  3.7
# RT_user_norm                                             4.3
# Metacritic_norm                                          3.3
# Metacritic_user_nom                                     3.55
# IMDB_norm                                                3.9
# RT_norm_round                                            3.5
# RT_user_norm_round                                       4.5
# ...

# %%
fandango_films[:'Avengers: Age of Ultron (2015)']
# Out:
#                                                           FILM  \
# FILM
# Avengers: Age of Ultron (2015)  Avengers: Age of Ultron (2015)
#
#                                 RottenTomatoes  RottenTomatoes_User  \
# FILM
# Avengers: Age of Ultron (2015)              74                   86
#
#                                 Metacritic  Metacritic_User  IMDB  \
# FILM
# Avengers: Age of Ultron (2015)          66              7.1   7.8
#
#                                 Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# FILM
# Avengers: Age of Ultron (2015)             5.0                   4.5      3.7
#
#                                 RT_user_norm         ...           IMDB_norm  \
# FILM                                                 ...
# Avengers: Age of Ultron (2015)           4.3         ...                 3.9
#
#                                 RT_norm_round  RT_user_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)            3.5                 4.5
#
# ...

# %%
fandango_films.loc['Avengers: Age of Ultron (2015)']
# Out:
# FILM                          Avengers: Age of Ultron (2015)
# RottenTomatoes                                            74
# RottenTomatoes_User                                       86
# Metacritic                                                66
# Metacritic_User                                          7.1
# IMDB                                                     7.8
# Fandango_Stars                                             5
# Fandango_Ratingvalue                                     4.5
# RT_norm                                                  3.7
# RT_user_norm                                             4.3
# Metacritic_norm                                          3.3
# Metacritic_user_nom                                     3.55
# IMDB_norm                                                3.9
# RT_norm_round                                            3.5
# RT_user_norm_round                                       4.5
# ...

# %%
best_movies_ever = fandango_films.loc[["The Lazarus Effect (2015)", "Gett: The Trial of Viviane Amsalem (2015)", "Mr. Holmes (2015)"]]
best_movies_ever
# Out:
#                                                                                 FILM  \
# FILM
# The Lazarus Effect (2015)                                  The Lazarus Effect (2015)
# Gett: The Trial of Viviane Amsalem (2015)  Gett: The Trial of Viviane Amsalem (2015)
# Mr. Holmes (2015)                                                  Mr. Holmes (2015)
#
#                                            RottenTomatoes  \
# FILM
# The Lazarus Effect (2015)                              14
# Gett: The Trial of Viviane Amsalem (2015)             100
# Mr. Holmes (2015)                                      87
#
#                                            RottenTomatoes_User  Metacritic  \
# FILM
# The Lazarus Effect (2015)                                   23          31
# Gett: The Trial of Viviane Amsalem (2015)                   81          90
# Mr. Holmes (2015)                                           78          67
#
# ...

# %%
best_movies_ever.std()
# Out:
# RottenTomatoes                  46.357308
# RottenTomatoes_User             32.654760
# Metacritic                      29.737743
# Metacritic_User                  1.587451
# IMDB                             1.400000
# Fandango_Stars                   0.500000
# Fandango_Ratingvalue             0.500000
# RT_norm                          2.317865
# RT_user_norm                     1.632738
# Metacritic_norm                  1.486887
# Metacritic_user_nom              0.793725
# IMDB_norm                        0.700000
# RT_norm_round                    2.466441
# RT_user_norm_round               1.732051
# Metacritic_norm_round            1.527525
# Metacritic_user_norm_round       0.763763
# IMDB_norm_round                  0.763763
# Metacritic_user_vote_count      21.931712
# IMDB_user_vote_count          7994.752612
# Fandango_votes                 845.359292
# Fandango_Difference              0.000000
# dtype: float64

# %%
# returns the data types as a Series
types = fandango_films.dtypes
# filter data types to just floats, index attributes returns just column names
float_columns = types[types.values == 'float64'].index
# use bracket notation to filter columns to just float columns
float_df = fandango_films[float_columns]

# `x` is a Series object representing a column
deviations = float_df.apply(lambda x: np.std(x))

print(deviations)
# Out:
# Metacritic_User               1.505529
# IMDB                          0.955447
# Fandango_Stars                0.538532
# Fandango_Ratingvalue          0.501106
# RT_norm                       1.503265
# RT_user_norm                  0.997787
# Metacritic_norm               0.972522
# Metacritic_user_nom           0.752765
# IMDB_norm                     0.477723
# RT_norm_round                 1.509404
# RT_user_norm_round            1.003559
# Metacritic_norm_round         0.987561
# Metacritic_user_norm_round    0.785412
# IMDB_norm_round               0.501043
# Fandango_Difference           0.152141
# dtype: float64

# %%
float_df.std()
# Out:
# Metacritic_User               1.510712
# IMDB                          0.958736
# Fandango_Stars                0.540386
# Fandango_Ratingvalue          0.502831
# RT_norm                       1.508440
# RT_user_norm                  1.001222
# Metacritic_norm               0.975869
# Metacritic_user_nom           0.755356
# IMDB_norm                     0.479368
# RT_norm_round                 1.514600
# RT_user_norm_round            1.007014
# Metacritic_norm_round         0.990961
# Metacritic_user_norm_round    0.788116
# IMDB_norm_round               0.502767
# Fandango_Difference           0.152665
# dtype: float64

# %%
double_df = float_df.apply(lambda x: x*2)
double_df.head()
# Out:
#                                 Metacritic_User  IMDB  Fandango_Stars  \
# FILM
# Avengers: Age of Ultron (2015)             14.2  15.6            10.0
# Cinderella (2015)                          15.0  14.2            10.0
# Ant-Man (2015)                             16.2  15.6            10.0
# Do You Believe? (2015)                      9.4  10.8            10.0
# Hot Tub Time Machine 2 (2015)               6.8  10.2             7.0
#
#                                 Fandango_Ratingvalue  RT_norm  RT_user_norm  \
# FILM
# Avengers: Age of Ultron (2015)                   9.0      7.4           8.6
# Cinderella (2015)                                9.0      8.5           8.0
# Ant-Man (2015)                                   9.0      8.0           9.0
# Do You Believe? (2015)                           9.0      1.8           8.4
# Hot Tub Time Machine 2 (2015)                    6.0      1.4           2.8
#
#                                 Metacritic_norm  Metacritic_user_nom  \
# ...

# %%
halved_df = float_df.apply(lambda x: x/2)
halved_df.head()
# Out:
#                                 Metacritic_User  IMDB  Fandango_Stars  \
# FILM
# Avengers: Age of Ultron (2015)             3.55  3.90            2.50
# Cinderella (2015)                          3.75  3.55            2.50
# Ant-Man (2015)                             4.05  3.90            2.50
# Do You Believe? (2015)                     2.35  2.70            2.50
# Hot Tub Time Machine 2 (2015)              1.70  2.55            1.75
#
#                                 Fandango_Ratingvalue  RT_norm  RT_user_norm  \
# FILM
# Avengers: Age of Ultron (2015)                  2.25    1.850          2.15
# Cinderella (2015)                               2.25    2.125          2.00
# Ant-Man (2015)                                  2.25    2.000          2.25
# Do You Believe? (2015)                          2.25    0.450          2.10
# Hot Tub Time Machine 2 (2015)                   1.50    0.350          0.70
#
#                                 Metacritic_norm  Metacritic_user_nom  \
# ...

# %%
rt_mt_user = float_df[['RT_user_norm', 'Metacritic_user_nom']]
rt_mt_user.apply(lambda x: np.std(x), axis=1).head()
# Out:
# FILM
# Avengers: Age of Ultron (2015)    0.375
# Cinderella (2015)                 0.125
# Ant-Man (2015)                    0.225
# Do You Believe? (2015)            0.925
# Hot Tub Time Machine 2 (2015)     0.150
# dtype: float64

# %%
rt_mt_user = float_df[['RT_user_norm', 'Metacritic_user_nom']]
rt_mt_deviations = rt_mt_user.apply(lambda x: np.std(x), axis=1)
rt_mt_deviations.head()
# Out:
# FILM
# Avengers: Age of Ultron (2015)    0.375
# Cinderella (2015)                 0.125
# Ant-Man (2015)                    0.225
# Do You Believe? (2015)            0.925
# Hot Tub Time Machine 2 (2015)     0.150
# dtype: float64

# %%
rt_mt_means = rt_mt_user.apply(lambda x: np.mean(x), axis=1)
rt_mt_means.head()
# Out:
# FILM
# Avengers: Age of Ultron (2015)    3.925
# Cinderella (2015)                 3.875
# Ant-Man (2015)                    4.275
# Do You Believe? (2015)            3.275
# Hot Tub Time Machine 2 (2015)     1.550
# dtype: float64
